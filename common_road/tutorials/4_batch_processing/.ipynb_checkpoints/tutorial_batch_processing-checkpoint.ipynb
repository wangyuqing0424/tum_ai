# %% [markdown]
# # Tutorial: Batch Processing
#
# This tutorial explains how to use the batch processing script to solve CommonRoad planning problems in parallel. The configuration for batch processing is stored in `batch_processing_config.yaml`. Some of the parameters are explained as follows:
# * **input_path**: input directory of your intended CommonRoad scenarios.
# * **output_path**: output directory of CommonRoad solution files.
# * **overwrite**: whether the existing solution files should be overwritten.
# * **validate_solution**: check the validity of the solutions with the feasibility checker.
# * **num_worker_processes**: the number of parallel executions of motion planners.
#
# Parameters specified under the `default` block will be applied to all scenarios. If you wish to specify a different paramter for specific scenarios, simply insert a new block with the content of the `default` block copied, and overwrite parameters therein. This new block should be named after the ID of the sceanrio that you wish to aplly the parameters to. Related parameters are explained as follows:
# * **vehicle_model**: model of the vehicle, valid values: **PM, KS, ST and MB**. Refer to [Vehicle Models](https://gitlab.lrz.de/tum-cps/commonroad-vehicle-models/-/blob/master/vehicleModels_commonRoad.pdf) for more information.
# * **vehicle_type**: type of the vehicle, valid values: **FORD_ESCORT, BMW_320i and VW_VANAGON**.
# * **cost_function**: id of cost function. Refer to [Cost Functions](https://gitlab.lrz.de/tum-cps/commonroad-cost-functions/-/blob/master/costFunctions_commonRoad.pdf) for more information.
# * **planner**: the planner that is used to solve for solutions, possible values are: bfs, dfs, dls, ucs, gbfs, astar, student, student_example
# * **planning_problem_idx**: index of the planning problem. for cooperative scenarios: 0, 1, 2, ..., otherwise: 0
# * **max_tree_depth**: maximum depth of the search tree
# * **timeout**: timeout time for motion planner [s].
#
# Note: the paths can either be **relative** or **absolute**.
# To start the search with batch processing, you can either directly run `SMP/batch_processing/batch_processing_parallel.py` in IDEs (e.g. PyCharm) with `commonroad-search/` marked as sources root, or run the following script.

# %% [markdown]
# ## Parallel Batch Processing
# In parallel batch processing, the search are carried out on multiple threads simultaneously. This reduces the overall time required to test your algorithm on all the given scenarios. One drawback is that it is not very easy to debug your code with parallel batch processing.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

# add the folder containing batch processing script into python path
sys.path.append(os.path.join(os.getcwd(), "../../"))

from SMP.batch_processing.batch_processing_parallel import run_parallel_processing

# %%
run_parallel_processing()
# Out:
# Config file loaded and logger created.
# 18 scenarios skipped.
# ScenarioLoader Mode <DEFAULT>
# Run on all scenarios, except the skipped scenarios
# Number of scenarios: 500
# Automaton loaded for vehicle type: BMW_320i
# Motion planner: astar
# Number of parallel processes: 4
#
# ==================================================
# Scenario being processed:	         1
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         2
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         3
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         4
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario ARG_Carcarana-13_1_T-1        ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[119.77036 909.17741]
# Received position=[120.95186834 908.3848433 ]
#
#
# ==================================================
# Scenario being processed:	         5
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario ARG_Carcarana-2_3_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ -42.345871 -160.47532 ]
# Received position=[ -40.9557694  -160.77820855]
#
# Something went wrong while processing scenario ARG_Carcarana-11_1_T-1        ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 4.8528764e-02 -3.2340290e+02]
# Received position=[   1.44568456 -323.67137644]
#
#
# ==================================================
# Scenario being processed:	         6
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         7
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario ARG_Carcarana-5_2_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 494.82773 -126.8882 ]
# Received position=[ 496.22706285 -127.14508814]
#
#
# ==================================================
# Scenario being processed:	         8
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario ARG_Carcarana-3_3_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 350.5634  -581.96265]
# Received position=[ 351.95521582 -582.25756124]
# ==================================================
# Scenario being processed:	         9
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        10
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Aarschot-11_1_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 978.34587 -134.32111]
# Received position=[ 978.1336582  -132.91430863]
#
#
# ==================================================
# Scenario being processed:	        11
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario ARG_Carcarana-7_1_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[369.30293 632.30164]
# Received position=[369.59696047 633.69364216]
#
#
# ==================================================
# Scenario being processed:	        12
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Aarschot-3_1_T-1          ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-257.22216 -211.03686]
# Received position=[-257.08557093 -212.45300524]
#
# Something went wrong while processing scenario BEL_Aarschot-1_2_T-1          ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-624.03791 -272.56536]
# Received position=[-624.06895297 -271.14298162]
#
#
# ==================================================
# Scenario being processed:	        13
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        14
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario ARG_Carcarana-9_2_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-135.79707  392.48165]
# Received position=[-136.07449687  391.08624387]
#
#
# ==================================================
# Scenario being processed:	        15
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Aarschot-5_1_T-1          ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-340.83927  517.00733]
# Received position=[-340.99528805  515.59319341]
#
#
# ==================================================
# Scenario being processed:	        16
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Beringen-8_1_T-1          ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[1000.9426   873.36308]
# Received position=[1002.02312645  874.28859959]
#
#
# ==================================================
# Scenario being processed:	        17
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        18
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Beringen-1_1_T-1          ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-372.76765  718.10163]
# Received position=[-374.06335778  717.51403723]
#
# Something went wrong while processing scenario BEL_Nivelles-16_2_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-500.27479 -487.31406]
# Received position=[-500.90810278 -488.58804542]
#
#
# ==================================================
# Scenario being processed:	        19
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        20
# Something went wrong while processing scenario BEL_Nivelles-10_1_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 254.87974 -988.86832]
# Received position=[ 256.29944913 -988.96078567]
#
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        21
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Nivelles-18_2_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-406.68424 -173.69798]
# Received position=[-406.24169312 -172.34584236]
# ==================================================
# Scenario being processed:	        22
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Nivelles-1_1_T-1          ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[861.1144  550.74041]
# Received position=[862.11473224 551.75207167]
#
# Something went wrong while processing scenario BEL_Nivelles-19_1_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-912.81802 -636.72001]
# Received position=[-913.99329303 -635.91822621]
#
#
# ==================================================
# Scenario being processed:	        23
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        24
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Nivelles-20_1_T-1         ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-883.77781 -626.00842]
# Received position=[-883.05163844 -624.78498271]
#
#
# ==================================================
# Scenario being processed:	        25
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Putte-10_2_T-1            ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[65.630609   1.1482173]
# Received position=[65.00450737  2.42576209]
#
#
# ==================================================
# Scenario being processed:	        26
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Nivelles-4_2_T-1          ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[712.78015 578.7309 ]
# Received position=[712.75595171 577.30838871]
#
# Something went wrong while processing scenario BEL_Putte-11_2_T-1            ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 313.42285 -473.63943]
# Received position=[ 314.80052628 -473.99458068]
# ==================================================
# Scenario being processed:	        27
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        28
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Nivelles-3_1_T-1          ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-923.52766 -629.01212]
# Received position=[-924.67999962 -628.17771163]
#
#
# ==================================================
# Scenario being processed:	        29
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Nivelles-9_2_T-1          ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 794.20686 -936.64096]
# Received position=[ 793.01079862 -937.41138917]
#
#
# ==================================================
# Scenario being processed:	        30
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         3
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        31
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         3
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        32
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Putte-3_1_T-1             ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 745.09359 -611.39303]
# Received position=[ 745.22868723 -612.80931834]
#
# Something went wrong while processing scenario BEL_Putte-2_1_T-1             ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[640.08333 973.80808]
# Received position=[640.90180832 974.97178837]
#
#
# ==================================================
# Scenario being processed:	        33
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        34
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Putte-6_1_T-1             ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 922.513   -456.17937]
# Received position=[ 923.77498321 -456.83627358]
# Something went wrong while processing scenario BEL_Putte-4_2_T-1             ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-716.88753 -779.29154]
# Received position=[-718.29075537 -779.05684339]
#
#
# ==================================================
# Scenario being processed:	        35
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        36
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Wervik-1_4_T-1            ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 83.586002 966.79291 ]
# Received position=[ 83.0087355  968.09325123]
#
#
# ==================================================
# Scenario being processed:	        37
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario BEL_Wervik-2_2_T-1            ]
# Traceback (most recent call last):
# ...
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-463.1657   205.09055]
# Received position=[-464.48722498  205.61751835]
#
#
# ==================================================
# Scenario being processed:	        55
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario DEU_BadWaldsee-4_2_T-1        ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 394.62151 -680.29984]
# Received position=[ 393.80545159 -679.13443337]
#
#
# ==================================================
# Scenario being processed:	        56
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario DEU_BadWaldsee-4_5_T-1        ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[ 394.15228 -679.64922]
# Received position=[ 393.31737075 -678.49724324]
#
#
# ==================================================
# Scenario being processed:	        57
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario DEU_BadEssen-3_1_T-1          ]Something went wrong while processing scenario DEU_BadWaldsee-1_1_T-1        ]
#
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-354.91696  575.70917]
# Received position=[-353.8353872  574.7848734]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-176.98395  112.56191]
# Received position=[-178.4063918   112.58989688]
#
#
#
# ==================================================
# Scenario being processed:	        58
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        59
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario DEU_Bilderstoeckchen-2_3_T-1  ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[381.50165 129.68371]
# Received position=[382.01112357 131.01207765]
#
#
# ==================================================
# Scenario being processed:	        60
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario DEU_Bilderstoeckchen-4_1_T-1  ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 1
# Expected position=[-286.47729  218.25314]
# Received position=[-285.10300022  217.88510259]
#
#
# ==================================================
# Scenario being processed:	        61
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Something went wrong while processing scenario DEU_Flensburg-13_1_T-1        ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 123
# Expected position=[151.11456 165.34444]
# Received position=[152.4177271  165.91529851]
#
#
# ==================================================
# Scenario being processed:	        62
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        63
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         1
# ==================================================
#
# ==================================================
# Scenario being processed:	        64
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         2
# ==================================================
# ==================================================
# Scenario being processed:	        65
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         3
# ==================================================
#
# ==================================================
# Scenario being processed:	        66
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         4
# ==================================================
#
# ==================================================
# Scenario being processed:	        67
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         5
# ==================================================
#
# ==================================================
# Scenario being processed:	        68
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         6
# ==================================================
#
# ==================================================
# Scenario being processed:	        69
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         7
# ==================================================
# Something went wrong while processing scenario DEU_Flensburg-20_1_T-1        ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 376, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 342, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 123
# Expected position=[ 45.699165 232.52175 ]
# Received position=[ 44.70079671 233.53534986]
#
#
# ==================================================
# Scenario being processed:	        70
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         7
# ==================================================

# %% [markdown]
# ## Sequential Batch Processing
#
# Alternatively, one can use the `SMP/batch_processing/batch_processing_sequential.py` script to carry out the search sequentially on a single thread. This is a more user-friendly approach if you wish you debug your code in IDES (e.g. creating breakpoints in PyCharm) but still have it run against multiple scenarios.

# %%
from SMP.batch_processing.batch_processing_sequential import run_sequential_processing
run_sequential_processing()
